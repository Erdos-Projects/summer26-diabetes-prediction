# %%
import pandas as pd
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.dummy import DummyClassifier
from sklearn.metrics import make_scorer, recall_score, f1_score

# %%
# ==========================================
# 1. Load Training Data ONLY
# ==========================================
# We only load train.csv. The test.csv remains untouched.
train_df = pd.read_csv('../data/processed/train.csv')

# %%
X_train = train_df.drop(columns=['Diabetes_012'])
y_train = train_df['Diabetes_012']

# %%
# ==========================================
# 2. Setup Stratified Cross-Validation
# ==========================================
# Define the 5-fold cross-validation blueprint
cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
# ==========================================
# 3. Initialize Dummy Classifier (Baseline)
# ==========================================
# 'most_frequent' means the model simply guesses the majority class every time
dummy_clf = DummyClassifier(strategy='most_frequent', random_state=42)

# %%
# ==========================================
# 4. Evaluate using cross_val_score
# ==========================================
print("--- Evaluating Dummy Classifier Baseline ---\n")
# A. Accuracy Score
acc_scores = cross_val_score(dummy_clf, X_train, y_train, cv=cv_strategy, scoring='accuracy')
print(f"Mean Accuracy: {acc_scores.mean():.4f}")

# B. Recall Score (Primary KPI)
# Using average='macro' because Diabetes_012 has 3 classes (0, 1, 2)
recall_scorer = make_scorer(recall_score, average='macro', zero_division=0)
recall_scores = cross_val_score(dummy_clf, X_train, y_train, cv=cv_strategy, scoring=recall_scorer)
print(f"Mean Recall:   {recall_scores.mean():.4f}")

# C. F1 Score (Secondary KPI)
f1_scorer = make_scorer(f1_score, average='macro', zero_division=0)
f1_scores = cross_val_score(dummy_clf, X_train, y_train, cv=cv_strategy, scoring=f1_scorer)
print(f"Mean F1-Score: {f1_scores.mean():.4f}")
# Out:
# --- Evaluating Dummy Classifier Baseline ---
#
# Mean Accuracy: 0.8271
# Mean Recall:   0.3333
# Mean F1-Score: 0.3018
